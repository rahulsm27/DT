# %%
# Type of data is indepenednt
# Target
# Categorical categorical and Categorical + Continours

# Also CART produces yes no tree.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#Decision trees have many techniques like ID3, C4.5, CART. 
# the model of XGBoost uses the CART to build decision trees in each step of the boosting process.

# %% [markdown]
# #CART always produces binary splits@

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#ID3

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
