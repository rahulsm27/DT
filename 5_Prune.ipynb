# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Here below SSR example is taken for regression. FOr classification we can take impurity.

# %%
# Pre-Pruning: this approach involves stopping the tree before it has completed fitting the training set. Pre-Pruning involves setting the model hyperparameters that control how large the tree can grow.
#
#  find the best values for max_depth, max_leaf_nodes, min_samples_split, and min_samples_leaf. We can make use of scikit-learn’s RandomizedSearchCV to find the optimal values for these hyperparameters:

# %%
"""
TRUNCATION

It stops the tree while it is still growing so that it may not end up with leaves containing very few data points. Truncation is also known as pre-pruning.

There are various methods that can be used to control the size of the tree or Truncation. Some of the methods are:

Limit the minimum size of the partition after the split: We can limit the number of data that a leaf should have to split.
Minimize change in the measure of homogeneity: If homogeneity measure doesn't change a lot we don't split further.
Limit the depth of the tree
Set a minimum threshold on the number of samples that appears in the leaf
Set the limit on the maximum number of leaves present in the tree.
"""

# %%
# Post-Pruning: here the tree is allowed to fit the training data perfectly, and subsequently it is truncated according to some criteria. The truncated tree is a simplified version of the original, with the least relevant branches having been removed.

# %%
#MEthod 1 - Weekest Link pruning or COST COMPLEXITY PRUNING (CC alpha parameter)

# %%
# Main idea is to prevent overfitting

# %%
# Fit a tree without any restriction. Full sized tree.. calclaute the SSR fo this tree
# remove one leaf at a time..caclaute the SSR for this tree
# keep repeate

# %%
# T is number of leaves

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# take alpha as 10000.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # alha 10000

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# How to dtermine the value of alpha

# STEP 1

# FIrst build treee using the WHOLE dataset..keep alpha 0..then keep on increasing alpha such that we get new tree with low tree sccore...in this way we will get different levels of alpha.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Step 2
#
# # use the above vlaues of alpha as candidate for below
# # Use CV - Divide data into training and test..use cross validation to determine on average with alpha gave us the lowest tree score on TESTING DATA

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Method 2 Reduced error

# %% [markdown]
# ![image.png](attachment:image.png)
