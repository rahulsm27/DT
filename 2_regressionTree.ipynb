# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Below sum of residuals for point less then 3..only one point before red line..

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Plot sum of residual for all threshold

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# multiple variables

# %% [markdown]
# ![image.png](attachment:image.png)
